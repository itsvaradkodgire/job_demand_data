# %% [markdown]
# ## Accessing Data

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df.loc[:10,'salary_year_avg':'salary_hour_avg']
# Out:
#     salary_year_avg  salary_hour_avg
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# 5               NaN              NaN
# 6               NaN              NaN
# 7               NaN              NaN
# 8               NaN              NaN
# 9               NaN              NaN
# 10              NaN              NaN

# %% [markdown]
# ## Data Cleaning

# %%
df0=df.copy()

# %%
y_median=df0['salary_year_avg'].median()

# %%
h_median=df0['salary_hour_avg'].median()

# %%
df1=df.copy()

# %%
df1['salary_year_avg']=df1['salary_year_avg'].fillna(y_median)

# %%
df1['salary_hour_avg']=df1['salary_hour_avg'].fillna(h_median)

# %%
df1
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df2=df1.copy()

# %%
df2=df2.drop_duplicates()

# %%
df2
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
len(df1)-len(df2)
# Out:
# 101

# %%
df2=df2.drop_duplicates(subset=['job_title','company_name'])

# %%
len(df2)
# Out:
# 508042

# %% [markdown]
# ## Data Management

# %%
df3=df.copy()

# %%
df3.sample(10,random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %%
df4=df.copy()

# %%
df4.pivot_table(values='salary_year_avg',index='job_title_short',aggfunc='median')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
df4.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
df4.pivot_table(values='salary_year_avg',index='job_country',columns='job_title_short',aggfunc='median')
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       NaN             NaN      49950.00
# Algeria                       NaN             NaN      44100.00
# Argentina                 71100.0        197500.0      92771.75
# Armenia                       NaN             NaN     100500.00
# Australia                 70000.0        110000.0     109500.00
# ...                           ...             ...           ...
# Uruguay                       NaN             NaN     100500.00
# Uzbekistan                    NaN             NaN           NaN
# Vietnam                   79200.0             NaN      75550.00
# Zambia                        NaN             NaN           NaN
# Zimbabwe                      NaN             NaN      63000.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN        69981.25                        NaN
# ...

# %%
top_countries=df4['job_country'].value_counts().head(6).index

# %%
df_job_country_salary=df4.pivot_table(values='salary_year_avg',index='job_country',columns='job_title_short',aggfunc='median')

# %%
df_job_country_salary=df_job_salary.loc[top_countries]

# %%
job_titles=['Data Analyst','Data Engineer','Data Scientist']

# %%
df_job_country_salary=df_job_country_salary[job_titles]

# %%
df_job_country_salary.plot(kind='bar')
plt.ylabel('median salary $usd')
plt.xlabel('')
plt.title('salary by contry for job title')
plt.xticks(rotation=45,ha='right')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df5=df.copy()

# %%
df5.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df5.index.name='job_index'

# %%
df5.index.dtype
# Out:
# dtype('int64')

# %%
df_usa=df5[df5['job_country']=='United States']

# %%
df_usa.reset_index(inplace=True)

# %%
df_usa
# Out:
#         job_index       job_title_short  \
# 0               0  Senior Data Engineer
# 1               3         Data Engineer
# 2               5         Data Engineer
# 3               6  Senior Data Engineer
# 4               9        Data Scientist
# ...           ...                   ...
# 206287     785673        Data Scientist
# 206288     785685          Data Analyst
# 206289     785692        Data Scientist
# 206290     785703          Data Analyst
# 206291     785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...
